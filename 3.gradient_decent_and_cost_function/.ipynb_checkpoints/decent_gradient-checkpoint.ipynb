# %% [markdown]
# Impliment $Gradient$ $decent$ and $Cost$ $function$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def gradient_decent(x,y):
    
    m_curr=p_curr=0
    itrations=2000
    n=len(x)
    learning_rate=0.005
    plt.scatter(x,y)
    for i in range(itrations):
        yp=m_curr*x+p_curr
        plt.plot(x,yp,color='green')
        cost=(1/n)*sum(val**2 for val in (y-yp))
        md=-(2/n)*sum(x*(y-yp))
        pd=-(2/n)*sum(y-yp)
        m_curr=m_curr-learning_rate*md
        p_curr=p_curr-learning_rate*pd
        
    print("m={}  ,p={}  ,cost={}  ,i={}".format(m_curr,p_curr,cost,i))
    pass
x=np.array([1,2,3,4,5])
y=np.array([5,7,11,13,15])
gradient_decent(x,y)
# Out:
# m=2.614656979352033  ,p=2.3470836539047983  ,cost=0.2405114019817107  ,i=1999
